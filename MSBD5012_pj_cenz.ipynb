# %% [markdown]
# <a href="https://colab.research.google.com/github/cenzwong/MSBD5012/blob/main/MSBD5012_pj_cenz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/online-ml/river --upgrade
# !pip install -U numpy
# Out:
# ...
#   Cloning https://github.com/online-ml/river to /tmp/pip-req-build-ursjhsad
#   Running command git clone -q https://github.com/online-ml/river /tmp/pip-req-build-ursjhsad
# ...

# %%
from river import datasets

# %%
datasets.trump_approval()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-0a19c67fe93c> in <module>()
# ----> 1 datasets.trump_approval()
#
# TypeError: 'module' object is not callable

# %%
help(datasets)
# Out:
# Help on package river.datasets in river:
#
# NAME
#     river.datasets - Datasets.
#
# DESCRIPTION
#     This module contains a collection of datasets for multiple tasks: classification, regression, etc.
#     The data corresponds to popular datasets and are conveniently wrapped to easily iterate over
#     the data in a stream fashion. All datasets have fixed size. Please refer to `river.synth` if you
#     are interested in infinite synthetic data generators.
#
# PACKAGE CONTENTS
#     airline_passengers
#     bananas
#     base
#     bikes
#     chick_weights
#     credit_card
#     elec2
#     higgs
#     http
#     insects
#     malicious_url
#     movielens100k
#     music
#     phishing
#     restaurants
#     segment
#     sms_spam
#     smtp
#     solar_flare
#     synth (package)
#     taxis
#     test_datasets
#     trec07
#     trump_approval
#
# CLASSES
#     river.datasets.base.FileDataset(river.datasets.base.Dataset)
# ...

# %%
from river import datasets

dataset = datasets.Restaurants()
print(dataset)
x, y = next(iter(dataset))
print(x)
print(y)
# Out:
# Data from the Kaggle Recruit Restaurants challenge.
#
# The goal is to predict the number of visitors in each of 829 Japanese restaurants over a priod
# of roughly 16 weeks. The data is ordered by date and then by restaurant ID.
#
#       Name  Restaurants
#       Task  Regression
#    Samples  252,108
#   Features  7
#     Sparse  False
#       Path  /root/river_data/Restaurants/kaggle_recruit_restaurants.csv
#        URL  https://maxhalford.github.io/files/datasets/kaggle_recruit_restaurants.zip
#       Size  27.54 MB
# Downloaded  False
# ...
# Uncompressing into /root/river_data/Restaurants
# {'store_id': 'air_04341b588bde96cd', 'date': datetime.datetime(2016, 1, 1, 0, 0), 'is_holiday': True, 'genre_name': 'Izakaya', 'area_name': 'Tōkyō-to Nerima-ku Toyotamakita', 'latitude': 35.7356234, 'longitude': 139.6516577}
# 10

# %%
""
